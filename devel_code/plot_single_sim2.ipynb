# %%
import sys, os
# Add .. to path to find module name
dir2=os.path.abspath('')
dir1=os.path.dirname(dir2)
if not dir1 in sys.path:
  sys.path.append(dir1)

# %%
from langevin_harmonic_osc_simulator import *

# %%
def center(t):
  if t < 5.0:
    return -5.0 + t
  else:
    return 0.0

# %%
simulator = Simulator(center=center)

# %%
simulator.run()

# %%
sim = simulator.simulation[0]

# %%
sim.plot_sim('x', [0, 10, 20, 50])

# %%
sim.results['x'][10]
# Out:
# array([-4.63465922, -4.75622664, -4.6631994 , -4.54928866, -4.28174589,
#        -4.42074669, -4.66558225, -3.65551376, -3.27013614, -3.18125265,
#        -3.58056305, -3.3415823 , -4.04611885, -4.43421653, -4.15198311,
#        -4.29883558, -4.0497733 , -4.13093803, -4.82330298, -5.26621206,
#        -4.9755883 , -3.97133316, -3.62909845, -3.73269479, -4.13695589,
#        -4.35068346, -4.13311105, -4.79035318, -4.66921075, -3.90852307,
#        -3.77167441, -3.74706532, -3.2851203 , -2.5221937 , -2.29813561,
#        -2.81824418, -2.55242504, -2.15518337, -1.79493232, -1.74668503,
#        -1.50815505, -2.000558  , -1.60566326, -1.39465104, -1.79100092,
#        -1.52763698, -1.92117417, -2.24260664, -2.63949519, -1.9410969 ,
#        -0.90661056, -0.13255053, -0.1624798 , -0.27378908, -1.18519871,
#        -0.85738911, -0.51327074, -0.76181957, -1.30956082, -1.70750791,
#        -1.69762665, -1.31200073, -0.76401661, -0.86965395, -1.11698286,
# ...

# %%
sim.plot_sim('x', [0])

# %%
sim.plot_sim('x', [0, 1])

# %%
sim.tot_sims
# Out:
# 1000

# %%
sim.plot_sim('x', [0, 2])

# %%
sim.plot_sim('x', [0, 2], ['sim 0', 'sim 2'])

# %%
sim.plot_sim('x', [2], ['sim 2'])

# %%
sim.plot_sim('x', [3], ['sim 3'])

# %%
sim.plot_sim('x', [0])

# %%
sim.plot_sim('work', [10, 20, 50, 500])

# %%
sim.plot_average('x')

# %%
sim.plot_average('work')

# %%
sim.plot_variance('work')
